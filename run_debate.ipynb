# %%
from autogen_orchestrator import AutoGenMOAOrchestrator
import config_api
# Biblioteka węzłów używana do generowania planów
NODE_LIBRARY = {
    'load_data': {'description': 'Wczytuje dane z różnych źródeł'},
    'clean_data': {'description': 'Czyści dane'},
    'validate_data': {'description': 'Waliduje dane'},
    'discover_causality': {'description': 'Odkrywa relacje przyczynowe (może zawieść)'},
    'error_handler': {'description': 'Obsługuje błędy'},
    'rollback': {'description': 'Cofa zmiany'},
    'generate_report': {'description': 'Generuje raport'},
    'validate_model': {'description': 'Waliduje model'},
    'optimize_performance': {'description': 'Optymalizuje wydajność'},
    'train_model': {'description': 'Uczy model'},
    'notify_user': {'description': 'Powiadamia użytkownika'}
}

# Możesz podać misję na stałe albo poprosić użytkownika o wpisanie
mission = input("Podaj opis misji: ").strip()
if not mission:
    mission = "Stwórz prosty pipeline do analizy danych CSV"

# Inicjalizacja orchestratora z definicją misji i ścieżką do konfiguracji agentów
orchestrator = AutoGenMOAOrchestrator(
    mission=mission,
    node_library=NODE_LIBRARY,
    config_file="agents_config.json"
)

# Uruchom pełną debatę; wynik to słownik z finalnym planem lub None
final_plan = orchestrator.run_full_debate_cycle()

# Wyświetl wynik w czytelnej formie
if final_plan:
    import json
    print("\n✅ Zatwierdzony plan:")
    print(json.dumps(final_plan, indent=2, ensure_ascii=False))
else:
    print("\n❌ Nie udało się uzyskać zatwierdzonego planu.")
# Out:
# Podaj opis misji:  Stwórz prosty pipeline do analizy danych CSV
# ======================================================================
# 🚀 STARTING AUTOGEN MOA DEBATE CYCLE
# ======================================================================
#
# 📍 Starting AutoGen group discussion...
# Orchestrator (to chat_manager):
#
#
#         ## MISSION: Stwórz prosty pipeline do analizy danych CSV
#
#         ## AVAILABLE TOOLS:
#         ["load_data", "clean_data", "validate_data", "discover_causality", "error_handler", "rollback", "generate_report", "validate_model", "optimize_performance", "train_model", "notify_user"]
#
#         ## TASK:
#         Create a robust workflow plan. Each agent should propose their approach,
#         then the aggregator will synthesize, and the critic will evaluate.
#
#         Iteration: 1/5
#
#
#
#         Please provide your proposal in JSON format with: plan, thought_process, confidence.
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: Causal_Analyst
# /opt/conda/envs/agents_with_memory_py11/lib/python3.11/site-packages/vertexai/generative_models/_generative_models.py:433: UserWarning: This feature is deprecated as of June 24, 2025 and will be removed on June 24, 2026. For details, see https://cloud.google.com/vertex-ai/generative-ai/docs/deprecations/genai-vertexai-sdk.
#   warning_logs.show_deprecation_warning()
# Causal_Analyst (to chat_manager):
#
# ```json
# {
#     "thought_process": [
#         "Krok 1: Dekompozycja problemu. Misja polega na stworzeniu pipeline'u do analizy danych CSV. Podstawowe kroki to: wczytanie, czyszczenie, walidacja, analiza i raportowanie.",
#         "Krok 2: Zastosowanie specjalistycznej wiedzy. Jako analityk przyczynowy, moim głównym celem jest przejście od prostych korelacji do zrozumienia fundamentalnych zależności przyczynowo-skutkowych w danych. Narzędzie `discover_causality` jest kluczowe dla tego celu. Stanowi ono rdzeń proponowanego przeze mnie workflow, odróżniając go od standardowej analizy opisowej.",
#         "Krok 3: Identyfikacja zmiennych i relacji. Pipeline musi najpierw przygotować dane (`load_data`, `clean_data`, `validate_data`), aby zapewnić wysoką jakość wejścia dla algorytmu odkrywania przyczynowości. Wynikiem `discover_causality` będzie hipoteza w postaci grafu przyczynowego.",
#         "Krok 4: Analiza trybów awarii (Failure Mode Analysis). Krok `discover_causality` jest najbardziej ryzykowny. Algorytmy te są wrażliwe na jakość danych, mogą być kosztowne obliczeniowo i mogą nie zwrócić sensownego wyniku. Dlatego kluczowe jest zdefiniowanie ścieżki awarii dla tego i innych kroków. Każdy krok, który może zawieść, musi być połączony z `error_handler`.",
#         "Krok 5: Projektowanie przepływu. Stworzyłem przepływ 'happy path' (ścieżka sukcesu) oraz ścieżki błędów. W przypadku błędu, `error_handler` przejmuje kontrolę, potencjalnie wykonując `rollback` i ostatecznie powiadamiając użytkownika. To zapewnia solidność (robustness) pipeline'u.",
#         "Krok 6: Kwantyfikacja niepewności. Wysoka pewność co do kroków ETL (Extract, Transform, Load) jest standardem. Jednak wprowadzenie `discover_causality` obniża ogólną pewność co do uzyskania *pożądanego wyniku* (tj. poprawnego grafu przyczynowego), chociaż pewność co do *poprawności działania samego pipeline'u* pozostaje wysoka dzięki obsłudze błędów. Ustalam pewność na 0.85, aby odzwierciedlić to ryzyko analityczne.",
#         "Krok 7: Definiowanie innowacji i mitygacji ryzyka. Kluczową innowacją jest skupienie się na przyczynowości. Główne ryzyko to zawodność lub mylące wyniki z `discover_causality`. Mitygacja polega na rygorystycznym przygotowaniu danych oraz, co najważniejsze, na transparentnym komunikowaniu w raporcie końcowym założeń i ograniczeń modelu przyczynowego (np. założenie o braku ukrytych zmiennych zakłócających - confounderów)."
#     ],
#     "plan": {
#         "entry_point": "Load_Data",
#         "nodes": [
#             {
#                 "name": "Load_Data",
#                 "implementation": "load_data"
#             },
#             {
#                 "name": "Clean_Data",
#                 "implementation": "clean_data"
#             },
#             {
#                 "name": "Validate_Data",
#                 "implementation": "validate_data"
#             },
#             {
#                 "name": "Discover_Causal_Relationships",
#                 "implementation": "discover_causality"
#             },
#             {
#                 "name": "Generate_Report",
#                 "implementation": "generate_report"
#             },
#             {
#                 "name": "Notify_User",
#                 "implementation": "notify_user"
#             },
#             {
#                 "name": "Error_Handler",
#                 "implementation": "error_handler"
#             }
#         ],
#         "edges": [
#             {
#                 "from": "Load_Data",
#                 "to": "Clean_Data",
#                 "condition": "on_success"
#             },
#             {
#                 "from": "Load_Data",
#                 "to": "Error_Handler",
#                 "condition": "on_failure"
#             },
#             {
#                 "from": "Clean_Data",
#                 "to": "Validate_Data",
#                 "condition": "on_success"
#             },
#             {
#                 "from": "Clean_Data",
#                 "to": "Error_Handler",
#                 "condition": "on_failure"
#             },
#             {
#                 "from": "Validate_Data",
#                 "to": "Discover_Causal_Relationships",
#                 "condition": "on_success"
#             },
#             {
#                 "from": "Validate_Data",
#                 "to": "Error_Handler",
#                 "condition": "on_failure"
#             },
#             {
#                 "from": "Discover_Causal_Relationships",
#                 "to": "Generate_Report",
#                 "condition": "on_success"
#             },
#             {
#                 "from": "Discover_Causal_Relationships",
#                 "to": "Error_Handler",
#                 "condition": "on_failure"
#             },
#             {
#                 "from": "Generate_Report",
#                 "to": "Notify_User"
#             },
#             {
#                 "from": "Error_Handler",
#                 "to": "Notify_User"
#             }
#         ]
#     },
#     "confidence": 0.85,
#     "key_innovations": [
#         "Analiza zorientowana na przyczynowość: Zamiast ograniczać się do korelacji, pipeline aktywnie próbuje odkryć fundamentalne struktury przyczynowo-skutkowe, co dostarcza głębszych i bardziej użytecznych wniosków.",
#         "Jawne modelowanie ryzyka analitycznego: Plan uwzględnia nie tylko błędy techniczne, ale także ryzyko związane z samą analizą (niepowodzenie odkrywania przyczynowości), co prowadzi do bardziej solidnego i realistycznego projektu."
#     ],
#     "risk_mitigation": {
#         "Misleading_Causal_Graph": "Ryzyko: Narzędzie `discover_causality` może wygenerować niepoprawny lub mylący graf przyczynowy z powodu ukrytych zmiennych zakłócających (confounders) lub niewystarczającej ilości danych. Mitygacja: 1) Rygorystyczne kroki czyszczenia i walidacji danych w celu zapewnienia jak najlepszej jakości danych wejściowych. 2) Raport końcowy musi jasno komunikować, że wygenerowany graf jest hipotezą, a nie ostateczną prawdą, oraz wymieniać kluczowe założenia (np. 'causal sufficiency' - brak ukrytych wspólnych przyczyn)."
#     }
# }
# ```
#
# --------------------------------------------------------------------------------
#
# Next speaker: Creative_Planner
#
# Creative_Planner (to chat_manager):
#
# ```json
# {
#     "thought_process": [
#         "Krok 1: Analiza istniejącej propozycji. Poprzednia propozycja skupia się na analizie przyczynowej - to świetny punkt wyjścia, ale jako Creative Planner widzę możliwości znacznych innowacji.",
#         "Krok 2: Zastosowanie SCAMPER - Substitute: Zamiast liniowego pipeline'u, co gdyby stworzyć adaptywną architekturę? Combine: Połączyć walidację z optymalizacją performance? Modify: Zmodyfikować przepływ, aby był samonaprawialny?",
#         "Krok 3: Lateral thinking - 3 alternatywne podejścia: 1) Self-healing pipeline z automatycznym rollback i retry, 2) Multi-path analysis z równoległym przetwarzaniem, 3) Adaptive workflow z ML-guided decision making.",
#         "Krok 4: Biomimicry - Jak działają systemy biologiczne? Mają redundancję, adaptację i samoregulację. Zaprojektuję pipeline inspirowany układem nerwowym - z węzłami decyzyjnymi i ścieżkami zapasowymi.",
#         "Krok 5: Constraint removal - Co gdyby pipeline mógł się uczyć i optymalizować? Dodaję mechanizm adaptacji, który uczy się z każdego uruchomienia i optymalizuje kolejne wykonania.",
#         "Krok 6: Innowacyjne połączenia - Łączę validation z model training dla continuous learning, optimize_performance działa proaktywnie, a nie reaktywnie.",
#         "Krok 7: Design for resilience - Każdy węzeł ma alternatywną ścieżkę, pipeline może się 'leczyć' i ewoluować."
#     ],
#     "plan": {
#         "entry_point": "Adaptive_Orchestrator",
#         "nodes": [
#             {"name": "Adaptive_Orchestrator", "implementation": "optimize_performance"},
#             {"name": "Data_Ingestion_Hub", "implementation": "load_data"},
#             {"name": "Intelligent_Cleaner", "implementation": "clean_data"},
#             {"name": "Smart_Validator", "implementation": "validate_data"},
#             {"name": "Causal_Discovery_Engine", "implementation": "discover_causality"},
#             {"name": "Learning_Model_Trainer", "implementation": "train_model"},
#             {"name": "Adaptive_Model_Validator", "implementation": "validate_model"},
#             {"name": "Self_Healing_Handler", "implementation": "error_handler"},
#             {"name": "Intelligent_Rollback", "implementation": "rollback"},
#             {"name": "Dynamic_Reporter", "implementation": "generate_report"},
#             {"name": "Context_Aware_Notifier", "implementation": "notify_user"}
#         ],
#         "edges": [
#             {"from": "Adaptive_Orchestrator", "to": "Data_Ingestion_Hub"},
#             {"from": "Data_Ingestion_Hub", "to": "Intelligent_Cleaner", "condition": "success"},
#             {"from": "Data_Ingestion_Hub", "to": "Self_Healing_Handler", "condition": "failure"},
#             {"from": "Intelligent_Cleaner", "to": "Smart_Validator", "condition": "success"},
#             {"from": "Intelligent_Cleaner", "to": "Self_Healing_Handler", "condition": "failure"},
#             {"from": "Smart_Validator", "to": "Causal_Discovery_Engine", "condition": "high_quality"},
#             {"from": "Smart_Validator", "to": "Learning_Model_Trainer", "condition": "medium_quality"},
#             {"from": "Smart_Validator", "to": "Self_Healing_Handler", "condition": "low_quality"},
#             {"from": "Causal_Discovery_Engine", "to": "Adaptive_Model_Validator", "condition": "success"},
#             {"from": "Causal_Discovery_Engine", "to": "Learning_Model_Trainer", "condition": "partial_success"},
#             {"from": "Causal_Discovery_Engine", "to": "Self_Healing_Handler", "condition": "failure"},
#             {"from": "Learning_Model_Trainer", "to": "Adaptive_Model_Validator"},
#             {"from": "Adaptive_Model_Validator", "to": "Dynamic_Reporter", "condition": "validated"},
#             {"from": "Adaptive_Model_Validator", "to": "Adaptive_Orchestrator", "condition": "needs_optimization"},
#             {"from": "Self_Healing_Handler", "to": "Intelligent_Rollback", "condition": "recoverable"},
#             {"from": "Self_Healing_Handler", "to": "Context_Aware_Notifier", "condition": "non_recoverable"},
#             {"from": "Intelligent_Rollback", "to": "Data_Ingestion_Hub", "condition": "retry"},
#             {"from": "Dynamic_Reporter", "to": "Context_Aware_Notifier"},
#             {"from": "Context_Aware_Notifier", "to": "Adaptive_Orchestrator", "condition": "feedback_loop"}
#         ]
#     },
#     "confidence": 0.78,
#     "key_innovations": [
#         "Self-Healing Adaptive Architecture: Pipeline nie tylko obsługuje błędy, ale uczy się z nich i adaptuje swoją strategię dla przyszłych uruchomień",
#         "Multi-Path Intelligence: Zamiast jednej ścieżki, system inteligentnie wybiera optymalną ścieżkę na podstawie jakości danych i kontekstu",
#         "Continuous Learning Integration: Każde uruchomienie pipeline'u dostarcza danych treningowych dla poprawy przyszłych analiz",
#         "Biomimetic Resilience: Inspirowana systemami biologicznymi redundancja i samoregulacja zapewniają wyjątkową odporność na awarie"
#     ],
#     "risk_mitigation": {
#         "Complexity_Overhead": "Ryzyko nadmiernej złożożności - Mitygacja: Modularny design z możliwością degradacji do prostszych ścieżek gdy zaawansowane funkcje zawodzą",
#         "Learning_Bias_Accumulation": "Ryzyko akumulacji błędów w uczeniu - Mitygacja: Periodic reset mechanizm i validation checkpoints",
#         "Performance_Degradation": "Ryzyko spadku wydajności przez nadmierną adaptację - Mitygacja: Performance monitoring z automatic fallback do baseline configuration"
#     }
# }
# ```
#
# --------------------------------------------------------------------------------
#
# Next speaker: Master_Aggregator
# /opt/conda/envs/agents_with_memory_py11/lib/python3.11/site-packages/autogen/oai/anthropic.py:712: UserWarning: Cost calculation not available for model claude-sonnet-4-20250514
#   warnings.warn(f"Cost calculation not available for model {model}", UserWarning)
# Master_Aggregator (to chat_manager):
#
# Please continue.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Quality_Critic
# /opt/conda/envs/agents_with_memory_py11/lib/python3.11/site-packages/autogen/oai/anthropic.py:712: UserWarning: Cost calculation not available for model claude-opus-4-1-20250805
#   warnings.warn(f"Cost calculation not available for model {model}", UserWarning)
# Quality_Critic (to chat_manager):
#
# ```json
# {
#     "critique_summary": {
#         "verdict": "ZATWIERDZONY",
#         "statement": "Plan jest zaawansowaną i dobrze przemyślaną syntezą dwóch początkowych propozycji. Skutecznie łączy solidność i przejrzystość pierwszego planu z innowacyjnymi, ale praktycznymi elementami drugiego. Wprowadza inteligentne, adaptacyjne ścieżki analizy w zależności od jakości danych, jednocześnie zachowując kompleksową i solidną obsługę błędów z mechanizmem rollback. Zidentyfikowano drobne słabości, głównie w postaci pojedynczych punktów awarii (SPOF) w krytycznych komponentach, ale ogólna jakość, innowacyjność i odporność planu są na bardzo wysokim poziomie. Plan jest wykonalny i w pełni realizuje cel misji.",
#         "key_strengths": [
#             "Adaptacyjna ścieżka analizy (Causal vs. Predictive) oparta na jakości danych.",
#             "Kompletne wykorzystanie dostępnych narzędzi w logiczny sposób.",
#             "Solidna obsługa błędów połączona z mechanizmem wycofywania zmian (rollback).",
#             "Wprowadzenie pętli zwrotnej w celu optymalizacji przyszłych wykonań."
#         ],
#         "identified_weaknesses": [
#             {
#                 "weakness": "Single Point of Failure (SPOF) w węźle 'Error_Handler'",
#                 "severity": "Medium",
#                 "description": "Jeśli sam mechanizm obsługi błędów ulegnie awarii, cały proces odzyskiwania po błędzie zawiedzie, potencjalnie pozostawiając system w nieznanym stanie bez powiadomienia."
#             },
#             {
#                 "weakness": "Niejasno zdefiniowana logika optymalizacji",
#                 "severity": "Low",
#                 "description": "Węzeł 'Optimize_Performance' jest koncepcyjnie silny, ale jego dokładny mechanizm działania (co i jak optymalizuje) nie jest sprecyzowany w planie."
#             },
#             {
#                 "weakness": "Potencjalna awaria mechanizmu Rollback",
#                 "severity": "Low",
#                 "description": "Plan nie precyzuje, co się stanie, jeśli operacja 'rollback' się nie powiedzie. Może to prowadzić do cichej awarii mechanizmu odzyskiwania."
#             }
#         ]
#     },
#     "quality_metrics": {
#         "Complexity_Score_C": 3.1,
#         "Robustness_Score_R": 50,
#         "Innovation_Score_I": 100,
#         "Completeness_Score": 100,
#         "Overall_Quality_Q": 84.07
#     },
#     "final_synthesized_plan": {
#         "entry_point": "Load_Data",
#         "nodes": [
#             { "name": "Load_Data", "implementation": "load_data" },
#             { "name": "Clean_Data", "implementation": "clean_data" },
#             { "name": "Validate_Data", "implementation": "validate_data" },
#             { "name": "Discover_Causality", "implementation": "discover_causality" },
#             { "name": "Train_Model", "implementation": "train_model" },
#             { "name": "Validate_Model", "implementation": "validate_model" },
#             { "name": "Generate_Report", "implementation": "generate_report" },
#             { "name": "Optimize_Performance", "implementation": "optimize_performance" },
#             { "name": "Notify_User", "implementation": "notify_user" },
#             { "name": "Error_Handler", "implementation": "error_handler" },
#             { "name": "Rollback_Changes", "implementation": "rollback" }
#         ],
#         "edges": [
#             { "from": "Load_Data", "to": "Clean_Data", "condition": "on_success" },
#             { "from": "Load_Data", "to": "Error_Handler", "condition": "on_failure" },
#             { "from": "Clean_Data", "to": "Validate_Data", "condition": "on_success" },
#             { "from": "Clean_Data", "to": "Error_Handler", "condition": "on_failure" },
#             { "from": "Validate_Data", "to": "Discover_Causality", "condition": "if data_quality > 0.9" },
#             { "from": "Validate_Data", "to": "Train_Model", "condition": "if data_quality > 0.6" },
#             { "from": "Validate_Data", "to": "Error_Handler", "condition": "else" },
#             { "from": "Discover_Causality", "to": "Generate_Report", "condition": "on_success" },
#             { "from": "Discover_Causality", "to": "Error_Handler", "condition": "on_failure" },
#             { "from": "Train_Model", "to": "Validate_Model" },
#             { "from": "Validate_Model", "to": "Generate_Report", "condition": "on_success" },
#             { "from": "Validate_Model", "to": "Error_Handler", "condition": "on_failure" },
#             { "from": "Generate_Report", "to": "Optimize_Performance" },
#             { "from": "Optimize_Performance", "to": "Notify_User" },
#             { "from": "Error_Handler", "to": "Rollback_Changes" },
#             { "from": "Rollback_Changes", "to": "Notify_User" }
#         ]
#     },
#     "improvement_suggestions": [
#         {
#             "id": 1,
#             "area": "Robustness",
#             "suggestion": "Wprowadzić redundantny, uproszczony mechanizm powiadamiania na wypadek awarii głównego 'Error_Handler' lub 'Rollback_Changes'.",
#             "example": "Dodać krawędź z 'Error_Handler' do 'Notify_User' z warunkiem 'on_rollback_failure', wysyłającą krytyczny alert o niemożności przywrócenia stanu systemu."
#         },
#         {
#             "id": 2,
#             "area": "Clarity & Automation",
#             "suggestion": "Sprecyzować działanie 'Optimize_Performance' poprzez zdefiniowanie jego wejść i wyjść.",
#             "example": "Węzeł 'Generate_Report' powinien generować metadane (np. czas wykonania, zużycie pamięci, rozmiar danych). 'Optimize_Performance' powinien odczytywać te metadane i aktualizować plik konfiguracyjny (np. `config.ini`) z parametrami dla następnego uruchomienia pipeline'u (np. `chunk_size`, `memory_allocation`)."
#         },
#         {
#             "id": 3,
#             "area": "Logic",
#             "suggestion": "Uczynić warunki brzegowe w węźle 'Validate_Data' jawnymi i mierzalnymi.",
#             "example": "Zamiast abstrakcyjnych warunków, użyć konkretnych, mierzalnych progów, jak w przedstawionym planie: `if data_quality > 0.9`. Należy zapewnić, że węzeł `validate_data` faktycznie zwraca metrykę `data_quality`."
#         }
#     ]
# }
# PLAN_ZATWIERDZONY
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (75259fba-b1f3-4c66-be2a-c0d7f0d59cf0): No next speaker selected
#
# ⚠️ No approved plan after debate
#
# ❌ Nie udało się uzyskać zatwierdzonego planu.
